# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

df_numeric = df.drop(['Name', 'Ticket', 'Cabin', 'Sex', 'Embarked'], axis=1)
print(df_numeric.describe(include='all'))

df_numeric.hist(bins=20, figsize=(12, 8))
plt.suptitle("Histograms of Numeric Features")
plt.show()

plt.figure(figsize=(10,5))
sns.boxplot(data=df_numeric[['Age','Fare']])
plt.title("Boxplots - Age & Fare")
plt.show()

plt.figure(figsize=(10,6))
sns.heatmap(df_numeric.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

sns.pairplot(df_numeric[['Survived','Age','Fare','Pclass']], hue='Survived')
plt.show()

fig = px.histogram(df_numeric, x="Age", color="Survived", barmode="overlay", nbins=30,
                   title="Age Distribution by Survival")
fig.show()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...
